# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import plotly.express as px
import plotly.graph_objects as go
from datetime import datetime


# Set options to display maximum rows and columns
pd.set_option('display.max_rows', None)  # Show all rows
pd.set_option('display.max_columns', None)  # Show all columns
pd.set_option('display.width', 1000)  # Set display width
pd.set_option('display.max_colwidth', None)  # Set maximum column width

# %% [markdown]
# ## **Analyzing Our Sales Data**

# %%
data_2023 = pd.read_csv("products_2023_complete_1.csv")
data_2023["Date"] = pd.to_datetime(data_2023["Date"])
data_2023.head()
# Out:
#         Date Product ID  Price ($)  Tax ($)  Total Price Paid by Client ($)  Quantity Ordered  Country
# 0 2023-01-01      P1001     278.92    27.89                          306.81                50  Germany
# 1 2023-01-01      P1002     430.39    43.04                          473.43                89   Canada
# 2 2023-01-01      P1003     315.55    31.56                          347.11                86    Japan
# 3 2023-01-01      P1004      37.79     3.78                           41.57                62       UK
# 4 2023-01-01      P1005     244.06    24.41                          268.47                89    Japan

# %%
overall_1 = data_2023[["Price ($)","Tax ($)","Quantity Ordered"]].groupby(data_2023["Date"].dt.month).sum()

# Replace month number with month name
overall_1.index = overall_1.index.map(lambda x: datetime(2023, x, 1).strftime('%B'))


# Create an interactive plot
fig = go.Figure()

# Add traces for Price, Tax, and Quantity Ordered with markers
fig.add_trace(go.Scatter(x=overall_1.index, y=overall_1["Price ($)"], mode='lines+markers', name='Monthly Sales ($)'))
fig.add_trace(go.Scatter(x=overall_1.index, y=overall_1["Tax ($)"], mode='lines+markers', name='Monthly Tax ($)'))
fig.add_trace(go.Scatter(x=overall_1.index, y=overall_1["Quantity Ordered"], mode='lines+markers', name='Quantity Ordered'))

# Update layout
fig.update_layout(
    title='Sales Report of 2023 (Monthly Basis)',
    xaxis_title='Month',
    yaxis_title='Amount ($)',
    legend_title_text='Metrics',
    xaxis=dict(
        tickmode='array',
        tickvals=list(overall_1.index),
        ticktext=list(overall_1.index)
    )
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="90858e6d-f3fa-46d2-823a-5cc547cc311f" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("90858e6d-f3fa-46d2-823a-5cc547cc311f")) {                    Plotly.newPlot(                        "90858e6d-f3fa-46d2-823a-5cc547cc311f",                        [{"mode":"lines+markers","name":"Monthly Sales ($)","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[159372.19,147922.98,152365.02,151866.22,159101.42,154387.98,154006.0,152298.82,147149.89,159772.5,151674.41,159400.16],"type":"scatter"},{"mode":"lines+markers","name":"Monthly Tax ($)","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[15937.28,14792.54,15236.48,15186.83,15910.33,15439.05,15400.78,15230.07,14715.18,15977.3,15167.63,15940.23],"type":"scatter"},{"mode":"lines+markers","name":"Quantity Ordered","x":["January","February","March","April","May","June","July","August","September","October","November","December"],"y":[46122,41838,46306,2985,3050,3076,46367,46403,44876,3088,2989,2976],"type":"scatter"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"so ...

# %%
# Group by Product ID and Country
product_country_sales = data_2023.groupby([data_2023["Date"].dt.month, 'Country','Product ID'])['Quantity Ordered'].sum().reset_index()

product_country_sales.rename(columns={"Date":"Month"},inplace = True)

product_country_sales.head()
# Out:
#    Month    Country Product ID  Quantity Ordered
# 0      1  Australia      P1001               203
# 1      1  Australia      P1002               123
# 2      1  Australia      P1003               137
# 3      1  Australia      P1004               281
# 4      1  Australia      P1005               175

# %%
# Aggregate the data to get the total quantity ordered for each product in each country
product_country_sales2 = data_2023.groupby(['Product ID', 'Country'])['Quantity Ordered'].sum().reset_index()

# Create a stacked bar chart using Plotly Express
fig = px.bar(
    product_country_sales2,
    x='Product ID',
    y='Quantity Ordered',
    color='Country',
    title='Total Quantity Ordered of Each Product in Each Country for 2023',
    labels={'Quantity Ordered': 'Total Quantity Ordered', 'Product ID': 'Product ID'},
    barmode='stack'
)

# Customize the layout
fig.update_layout(
    xaxis_title='Product ID',
    yaxis_title='Total Quantity Ordered',
    legend_title='Country',
    width=1200,
    height=700
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f73d12a9-a969-48fe-9fe3-03bc74cb3b1f" class="plotly-graph-div" style="height:700px; width:1200px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f73d12a9-a969-48fe-9fe3-03bc74cb3b1f")) {                    Plotly.newPlot(                        "f73d12a9-a969-48fe-9fe3-03bc74cb3b1f",                        [{"alignmentgroup":"True","hovertemplate":"Country=Australia\u003cbr\u003eProduct ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Australia","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"Australia","offsetgroup":"Australia","orientation":"v","showlegend":true,"textposition":"auto","x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"xaxis":"x","y":[1783,2184,1761,1838,1950,2065,2065,2212,1737,1895,2111,2012,2340,2842,1353,1736,1977,2714,2474,2103],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=Canada\u003cbr\u003eProduct ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Canada","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"Canada","offsetgroup":"Canada","orientation":"v","showlegend":true,"textposition":"auto","x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"xaxis":"x","y":[1600,1566,1746,2146,2423,2278,2157,1968,2456,1554,1849,1966,1415,1623,3165,2450,1930,1456,1934,2168],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=France\u003cbr\u003eProduct ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"France","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"France","offsetgroup":"France","orientation":"v","showlegend":true,"textposition":"auto","x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"xaxis":"x","y":[2163,2862,1577,1654,2043,2783,2551,2494,2240,2352,2678,2310,2328,2520,983,1964,2066,2451,1689,2068],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=Germany\u003cbr\u003eProduct ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Germany","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"Germany","offsetgroup":"Germany","orientation":"v","showlegend":true,"textposition":"auto","x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"xaxis":"x","y":[2529,2477,2474,2376,1964,1930,1617,1878,2325,2821,2295,2134,2029,1431,2379,2192,1842,1919,2548,2811],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=Japan\u003cbr\u003eProduct ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"Japan","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"Japan","offsetgroup":"Japan","orientation":"v","showlegend":true,"textposition":"auto","x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"xaxis":"x","y":[2667,1849,2510,1844,2075,1994,2145,2197,1953,1901,1827,2449,2097,2090,2310,1992,2324,1959,2044,1175],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Country=UK\u003cbr\u003eProduct ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgr ...

# %%
overall_product_country_sales = data_2023.groupby(['Product ID',"Country"])['Total Price Paid by Client ($)'].sum().reset_index()

overall_product_country_sales.head()
# Out:
#   Product ID    Country  Total Price Paid by Client ($)
# 0      P1001  Australia                        13827.00
# 1      P1001     Canada                        12773.17
# 2      P1001     France                        15268.58
# 3      P1001    Germany                        15068.48
# 4      P1001      Japan                        16282.97

# %%
import plotly.graph_objects as go

# Create a figure
fig = go.Figure()

# Add traces for each country
countries = overall_product_country_sales['Country'].unique()
for country in countries:
    subset = overall_product_country_sales[overall_product_country_sales['Country'] == country]
    fig.add_trace(go.Bar(
        x=subset['Product ID'],
        y=subset['Total Price Paid by Client ($)'],
        name=country,
        visible=(country == countries[0])
    ))

# Create dropdown menu
dropdown_buttons = [
    dict(
        args=[
            {"visible": [country == c for c in countries]},
            {"annotations": [
                dict(
                    x=0.5,
                    y=1.15,
                    xref='paper',
                    yref='paper',
                    showarrow=False,
                    text="Product Sales Record per Country",
                    font=dict(size=18, family="Times New Roman"),
                ),
                dict(
                    x=0.5,
                    y=1.08,
                    xref='paper',
                    yref='paper',
                    showarrow=False,
                    text=f"Currently Displaying: {country}",
                    font=dict(size=14),
                )
            ]}
        ],
        label=country,
        method="update",
    ) for country in countries
]

# Add a button to show all countries
dropdown_buttons.append(
    dict(
        args=[
            {"visible": [True] * len(countries)},
            {"annotations": [
                dict(
                    x=0.5,
                    y=1.15,
                    xref='paper',
                    yref='paper',
                    showarrow=False,
                    text="Product Sales Record per Country",
                    font=dict(size=18, family="Times New Roman"),
                ),
                dict(
                    x=0.5,
                    y=1.08,
                    xref='paper',
                    yref='paper',
                    showarrow=False,
                    text="Currently Displaying: All Countries",
                    font=dict(size=14),
                )
            ]}
        ],
        label="All",
        method="update",
    )
)

# Update layout with dropdown menu and initial annotations
fig.update_layout(
    updatemenus=[
        dict(
            active=0,
            buttons=dropdown_buttons,
            direction="down",
            showactive=True,
        )
    ],
    annotations=[
        dict(
            x=0.5,
            y=1.15,
            xref='paper',
            yref='paper',
            showarrow=False,
            text="Product Sales Record per Country",
            font=dict(size=22, family="Times New Roman,bold"),
        ),
        dict(
            x=0.5,
            y=1.08,
            xref='paper',
            yref='paper',
            showarrow=False,
            text="",
            font=dict(size=14),
        )
    ],
    xaxis_title="Product ID",
    yaxis_title="Sales ($)",
    barmode='stack',  # Making the stacked bar chart
    legend_title="Country",  # Add legend title
    width=1400,
    height=600,
)

fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="2736b5ec-998c-4b16-b841-ded63e127fe9" class="plotly-graph-div" style="height:600px; width:1400px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("2736b5ec-998c-4b16-b841-ded63e127fe9")) {                    Plotly.newPlot(                        "2736b5ec-998c-4b16-b841-ded63e127fe9",                        [{"name":"Australia","visible":true,"x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"y":[13827.0,15761.289999999999,14373.2,14672.78,14561.56,16821.57,15198.98,13816.74,10713.39,11672.98,12471.92,16769.67,16007.22,12766.97,10659.02,15680.07,15007.9,15091.88,18146.27,11782.03],"type":"bar"},{"name":"Canada","visible":false,"x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"y":[12773.17,12202.26,14183.32,13417.91,16105.44,15382.09,15346.33,14308.17,15817.75,12927.31,13542.630000000001,16071.89,13332.66,13145.81,16725.82,15827.55,16457.29,14187.57,14153.73,16806.04],"type":"bar"},{"name":"France","visible":false,"x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"y":[15268.58,15010.539999999999,12222.82,13394.61,13169.56,17746.62,16820.36,16445.28,16733.59,13782.44,16756.78,18144.45,15210.84,18674.37,7904.96,10295.119999999999,15931.46,14743.98,14825.28,16439.76],"type":"bar"},{"name":"Germany","visible":false,"x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"y":[15068.48,15958.83,16254.06,16423.83,14481.97,11673.85,11226.96,14307.44,14780.55,18846.93,11674.47,14636.13,14099.78,14088.41,15513.53,14507.55,11720.52,14634.98,16466.73,15718.47],"type":"bar"},{"name":"Japan","visible":false,"x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"y":[16282.97,13808.74,16466.33,13840.42,14862.43,14721.5,18090.36,15197.69,14825.58,14950.380000000001,12582.24,16864.09,13575.78,12149.65,16618.86,12501.91,13683.61,13218.73,10694.6,11875.6],"type":"bar"},{"name":"UK","visible":false,"x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"y":[15034.94,14784.81,15520.03,13766.03,13882.8,18170.86,13328.369999999999,10614.24,14977.31,11933.98,18762.57,12983.16,14610.15,14210.77,18437.84,16521.36,15772.85,16161.59,10028.16,13433.36],"type":"bar"},{"name":"USA","visible":false,"x":["P1001","P1002","P1003","P1004","P1005","P1006","P1007","P1008","P1009","P1010","P1011","P1012","P1013","P1014","P1015","P1016","P1017","P1018","P1019","P1020"],"y":[12486.12,13842.56,19957.23,16215.44,15947.630000000001,13208.33,13137.33,14434.710000000001,9920.49,16296.92,12714.04,12401.15,13166.55,18504.73,11110.91,13217.6,16805.94,13436.95,16852.85,10725.11],"type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth" ...

# %%
data_2023.head()
# Out:
#         Date Product ID  Price ($)  Tax ($)  Total Price Paid by Client ($)  Quantity Ordered  Country
# 0 2023-01-01      P1001     278.92    27.89                          306.81                50  Germany
# 1 2023-01-01      P1002     430.39    43.04                          473.43                89   Canada
# 2 2023-01-01      P1003     315.55    31.56                          347.11                86    Japan
# 3 2023-01-01      P1004      37.79     3.78                           41.57                62       UK
# 4 2023-01-01      P1005     244.06    24.41                          268.47                89    Japan

# %%
import pandas as pd

# Assuming data_2023 is your dataset

# Group by "Country" and "Product ID", summing up the "Quantity Ordered"
top_products_by_country = data_2023.groupby(["Country", "Product ID"])["Quantity Ordered"].sum().reset_index()

# Sort by "Country" and the sum of "Quantity Ordered" within each country in descending order
top_products_by_country = top_products_by_country.sort_values(by=["Country", "Quantity Ordered"], ascending=[True, False])

# Get the top 20 products for each country
top_products_by_country = top_products_by_country.groupby("Country").head(5).reset_index(drop=True)

# Display the top products for each country
top_products_by_country.head()
# Out:
#      Country Product ID  Quantity Ordered
# 0  Australia      P1014              2842
# 1  Australia      P1018              2714
# 2  Australia      P1019              2474
# 3  Australia      P1013              2340
# 4  Australia      P1008              2212

# %%
# Sort by "Country" and the sum of "Quantity Ordered" within each country in descending order
top_products_by_country = top_products_by_country.sort_values(by=["Country", "Quantity Ordered"], ascending=[True, False])

# Get the top 5 products for each country
top_products_by_country = top_products_by_country.groupby("Country").head(5).reset_index(drop=True)

# Plotting each country's top products separately
for country in top_products_by_country['Country'].unique():
    country_data = top_products_by_country[top_products_by_country['Country'] == country]

    fig = px.bar(country_data,
                 x='Product ID',
                 y='Quantity Ordered',
                 color='Product ID',
                 labels={'Quantity Ordered': 'Total Quantity Ordered', 'Product ID': 'Top Product ID'},
                 title=f'Top 5 Ordered Products in {country}',
                 height=400,
                 width=800
                )

    # Customize layout
    fig.update_layout(
        xaxis_title='Top Product ID',
        yaxis_title='Total Quantity Ordered',
        legend_title='Product ID',
        barmode='stack',  # Display bars in groups
    )

    # Show the figure
    fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="68ec12e3-f8c4-49db-880a-a1052cfb725b" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("68ec12e3-f8c4-49db-880a-a1052cfb725b")) {                    Plotly.newPlot(                        "68ec12e3-f8c4-49db-880a-a1052cfb725b",                        [{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1014","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"P1014","offsetgroup":"P1014","orientation":"v","showlegend":true,"textposition":"auto","x":["P1014"],"xaxis":"x","y":[2842],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1018","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"P1018","offsetgroup":"P1018","orientation":"v","showlegend":true,"textposition":"auto","x":["P1018"],"xaxis":"x","y":[2714],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1019","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"P1019","offsetgroup":"P1019","orientation":"v","showlegend":true,"textposition":"auto","x":["P1019"],"xaxis":"x","y":[2474],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1013","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"P1013","offsetgroup":"P1013","orientation":"v","showlegend":true,"textposition":"auto","x":["P1013"],"xaxis":"x","y":[2340],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1008","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"P1008","offsetgroup":"P1008","orientation":"v","showlegend":true,"textposition":"auto","x":["P1008"],"xaxis":"x","y":[2212],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="f62ca4b8-95e7-4a29-8c9d-5da4beefd1fb" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("f62ca4b8-95e7-4a29-8c9d-5da4beefd1fb")) {                    Plotly.newPlot(                        "f62ca4b8-95e7-4a29-8c9d-5da4beefd1fb",                        [{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1015","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"P1015","offsetgroup":"P1015","orientation":"v","showlegend":true,"textposition":"auto","x":["P1015"],"xaxis":"x","y":[3165],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1009","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"P1009","offsetgroup":"P1009","orientation":"v","showlegend":true,"textposition":"auto","x":["P1009"],"xaxis":"x","y":[2456],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1016","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"P1016","offsetgroup":"P1016","orientation":"v","showlegend":true,"textposition":"auto","x":["P1016"],"xaxis":"x","y":[2450],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1005","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"P1005","offsetgroup":"P1005","orientation":"v","showlegend":true,"textposition":"auto","x":["P1005"],"xaxis":"x","y":[2423],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1006","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"P1006","offsetgroup":"P1006","orientation":"v","showlegend":true,"textposition":"auto","x":["P1006"],"xaxis":"x","y":[2278],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="bfb63374-1803-4816-baef-28b9de1f925e" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("bfb63374-1803-4816-baef-28b9de1f925e")) {                    Plotly.newPlot(                        "bfb63374-1803-4816-baef-28b9de1f925e",                        [{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1002","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"P1002","offsetgroup":"P1002","orientation":"v","showlegend":true,"textposition":"auto","x":["P1002"],"xaxis":"x","y":[2862],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1006","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"P1006","offsetgroup":"P1006","orientation":"v","showlegend":true,"textposition":"auto","x":["P1006"],"xaxis":"x","y":[2783],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1011","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"P1011","offsetgroup":"P1011","orientation":"v","showlegend":true,"textposition":"auto","x":["P1011"],"xaxis":"x","y":[2678],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1007","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"P1007","offsetgroup":"P1007","orientation":"v","showlegend":true,"textposition":"auto","x":["P1007"],"xaxis":"x","y":[2551],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1014","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"P1014","offsetgroup":"P1014","orientation":"v","showlegend":true,"textposition":"auto","x":["P1014"],"xaxis":"x","y":[2520],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="e44b32c7-e888-40b4-a683-942fdc87fcff" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("e44b32c7-e888-40b4-a683-942fdc87fcff")) {                    Plotly.newPlot(                        "e44b32c7-e888-40b4-a683-942fdc87fcff",                        [{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1010","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"P1010","offsetgroup":"P1010","orientation":"v","showlegend":true,"textposition":"auto","x":["P1010"],"xaxis":"x","y":[2821],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1020","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"P1020","offsetgroup":"P1020","orientation":"v","showlegend":true,"textposition":"auto","x":["P1020"],"xaxis":"x","y":[2811],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1019","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"P1019","offsetgroup":"P1019","orientation":"v","showlegend":true,"textposition":"auto","x":["P1019"],"xaxis":"x","y":[2548],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1001","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"P1001","offsetgroup":"P1001","orientation":"v","showlegend":true,"textposition":"auto","x":["P1001"],"xaxis":"x","y":[2529],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1002","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"P1002","offsetgroup":"P1002","orientation":"v","showlegend":true,"textposition":"auto","x":["P1002"],"xaxis":"x","y":[2477],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="c6284c17-1869-4092-9963-62eafbfc2436" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c6284c17-1869-4092-9963-62eafbfc2436")) {                    Plotly.newPlot(                        "c6284c17-1869-4092-9963-62eafbfc2436",                        [{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1001","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"P1001","offsetgroup":"P1001","orientation":"v","showlegend":true,"textposition":"auto","x":["P1001"],"xaxis":"x","y":[2667],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1003","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"P1003","offsetgroup":"P1003","orientation":"v","showlegend":true,"textposition":"auto","x":["P1003"],"xaxis":"x","y":[2510],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1012","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"P1012","offsetgroup":"P1012","orientation":"v","showlegend":true,"textposition":"auto","x":["P1012"],"xaxis":"x","y":[2449],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1017","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"P1017","offsetgroup":"P1017","orientation":"v","showlegend":true,"textposition":"auto","x":["P1017"],"xaxis":"x","y":[2324],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1015","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"P1015","offsetgroup":"P1015","orientation":"v","showlegend":true,"textposition":"auto","x":["P1015"],"xaxis":"x","y":[2310],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="44fea51c-7b46-47b9-acde-cc46dd1fa3a4" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("44fea51c-7b46-47b9-acde-cc46dd1fa3a4")) {                    Plotly.newPlot(                        "44fea51c-7b46-47b9-acde-cc46dd1fa3a4",                        [{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1011","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"P1011","offsetgroup":"P1011","orientation":"v","showlegend":true,"textposition":"auto","x":["P1011"],"xaxis":"x","y":[2370],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1013","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"P1013","offsetgroup":"P1013","orientation":"v","showlegend":true,"textposition":"auto","x":["P1013"],"xaxis":"x","y":[2339],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1020","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"P1020","offsetgroup":"P1020","orientation":"v","showlegend":true,"textposition":"auto","x":["P1020"],"xaxis":"x","y":[2241],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1015","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"P1015","offsetgroup":"P1015","orientation":"v","showlegend":true,"textposition":"auto","x":["P1015"],"xaxis":"x","y":[2209],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1001","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"P1001","offsetgroup":"P1001","orientation":"v","showlegend":true,"textposition":"auto","x":["P1001"],"xaxis":"x","y":[2166],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.35.2.min.js"></script>                <div id="7f4833f6-765b-4cf7-aa50-fe2bd917f4e9" class="plotly-graph-div" style="height:400px; width:800px;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7f4833f6-765b-4cf7-aa50-fe2bd917f4e9")) {                    Plotly.newPlot(                        "7f4833f6-765b-4cf7-aa50-fe2bd917f4e9",                        [{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1003","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"P1003","offsetgroup":"P1003","orientation":"v","showlegend":true,"textposition":"auto","x":["P1003"],"xaxis":"x","y":[2795],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1004","marker":{"color":"#EF553B","pattern":{"shape":""}},"name":"P1004","offsetgroup":"P1004","orientation":"v","showlegend":true,"textposition":"auto","x":["P1004"],"xaxis":"x","y":[2733],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1017","marker":{"color":"#00cc96","pattern":{"shape":""}},"name":"P1017","offsetgroup":"P1017","orientation":"v","showlegend":true,"textposition":"auto","x":["P1017"],"xaxis":"x","y":[2521],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1016","marker":{"color":"#ab63fa","pattern":{"shape":""}},"name":"P1016","offsetgroup":"P1016","orientation":"v","showlegend":true,"textposition":"auto","x":["P1016"],"xaxis":"x","y":[2483],"yaxis":"y","type":"bar"},{"alignmentgroup":"True","hovertemplate":"Top Product ID=%{x}\u003cbr\u003eTotal Quantity Ordered=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"P1010","marker":{"color":"#FFA15A","pattern":{"shape":""}},"name":"P1010","offsetgroup":"P1010","orientation":"v","showlegend":true,"textposition":"auto","x":["P1010"],"xaxis":"x","y":[2476],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777 ...
